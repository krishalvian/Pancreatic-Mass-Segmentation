# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from matplotlib import pyplot as plt
from numpy import expand_dims
import os

# %%
# source_folder = '/content/drive/MyDrive/Skripsi/Dataset/Mark/Cropped'

# %%
# Load gambar
img = load_img('/content/drive/MyDrive/Skripsi/Dataset/Raw/R-12.jpg')  # Ganti path sesuai lokasi gambarmu
data = img_to_array(img)
samples = expand_dims(data, 0)

# Konfigurasi augmentasi
datagen = ImageDataGenerator(
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# Inisialisasi generator
it = datagen.flow(samples, batch_size=1)

# Tampilkan hasil
fig = plt.figure(figsize=(15, 10))
columns, rows = 3, 3
for i in range(columns * rows):
    batch = next(it)
    image = batch[0].astype('uint8')
    fig.add_subplot(rows, columns, i + 1)
    plt.imshow(image)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Load gambar
img = load_img('/content/drive/MyDrive/Skripsi/Dataset/Binary/12_mask.jpg')  # Ganti path sesuai lokasi gambarmu
data = img_to_array(img)
samples = expand_dims(data, 0)

# Konfigurasi augmentasi
datagen = ImageDataGenerator(
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# Inisialisasi generator
it = datagen.flow(samples, batch_size=1)

# Tampilkan hasil
fig = plt.figure(figsize=(15, 10))
columns, rows = 3, 3
for i in range(columns * rows):
    batch = next(it)
    image = batch[0].astype('uint8')
    fig.add_subplot(rows, columns, i + 1)
    plt.imshow(image)
    plt.axis('off')
plt.tight_layout()
plt.show()
