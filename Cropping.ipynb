# %% [markdown]
# <a href="https://colab.research.google.com/github/krishalvian/Pancreatic-Mass-Segmentation/blob/main/Cropping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cropping Image**

# %% [markdown]
# Menghubungkan Google Drive dengan Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Mengimpor modul PIL dan matplotlib yang digunakan pada percobaan ini

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Menentukan gambar yang ingin dilakukan *cropping*

# %%
folder_path = "/content/drive/MyDrive/Dataset/Raw/Data/train/Raw/"
output_folder = "/content/drive/MyDrive/Dataset/Raw/Data/train/Processed/"

# %%
# Menentukan pixel yang ingin di crop
left = 170
top = 80
right = 550
bottom = 410

for filename in os.listdir(folder_path):
    if filename.lower().endswith((".jpg")):
        image_path = os.path.join(folder_path, filename)
        image = Image.open(image_path)

        cropped_image = image.crop((left, top, right, bottom))

        cropped_image_path = os.path.join(output_folder, f"cropped_{filename}")
        cropped_image.save(cropped_image_path)
        print(f"Cropped image saved: {cropped_image_path}")
# Out:
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4804097_Rep#5#2.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4804097_Rep#5#1.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4804097_Rep#5#3.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4804097_Rep#5#4.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4726067_Rep#1#5.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4726067_Rep#1#4.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4726067_Rep#1#6.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4778583_Rep#1#6.jpg
# Cropped image saved: /content/drive/MyDrive/Dataset/Raw/Data/train/Processed/cropped_4778583_Rep#1#3.jpg
# ...

# %%
plt.imshow(cropped_image)
plt.axis("off")
plt.show()

# %% [markdown]
# Gambar diatas merupakan hasil dari proses *cropping*
